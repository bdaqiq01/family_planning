# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement pyplot (from versions: none)
# ERROR: No matching distribution found for pyplot
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Provisional_Natality_2023_jan_2024.txt', sep = '\t')
dataset.info()
dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16583 entries, 0 to 16582
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Notes                                28 non-null     object
#  1   State of Residence                   16555 non-null  object
#  2   State of Residence Code              16555 non-null  float64
#  3   Age of Mother 9                      16555 non-null  object
#  4   Age of Mother 9 Code                 16555 non-null  object
#  5   Mother's Single Race 6               16555 non-null  object
#  6   Mother's Single Race 6 Code          16555 non-null  object
#  7   Mother's Education                   16555 non-null  object
#  8   Mother's Education Code              16555 non-null  object
#  9   Source of Payment for Delivery       16555 non-null  object
#  10  Source of Payment for Delivery Code  16555 non-null  float64
#  11  Births                               16555 non-null  float64
#  12  % of Total Births                    16555 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.6+ MB
#   Notes State of Residence  State of Residence Code Age of Mother 9  \
# 0   NaN            Alabama                      1.0  Under 15 years
# 1   NaN            Alabama                      1.0  Under 15 years
# 2   NaN            Alabama                      1.0     15-19 years
# 3   NaN            Alabama                      1.0     15-19 years
# 4   NaN            Alabama                      1.0     15-19 years
#
#   Age of Mother 9 Code     Mother's Single Race 6 Mother's Single Race 6 Code  \
# 0                   15  Black or African American                      2054-5
# 1                   15                      White                      2106-3
# 2                15-19  Black or African American                      2054-5
# 3                15-19  Black or African American                      2054-5
# 4                15-19  Black or African American                      2054-5
#
#                        Mother's Education Mother's Education Code  \
# 0                       8th grade or less                       1
# 1                       8th grade or less                       1
# 2                       8th grade or less                       1
# 3  9th through 12th grade with no diploma                       2
# 4  9th through 12th grade with no diploma                       2
#
#   Source of Payment for Delivery  Source of Payment for Delivery Code  Births  \
# 0                       Medicaid                                  1.0    17.0
# 1                       Medicaid                                  1.0    16.0
# 2                       Medicaid                                  1.0    28.0
# 3                       Medicaid                                  1.0   424.0
# 4              Private Insurance                                  2.0    31.0
#
#   % of Total Births
# 0             0.00%
# 1             0.00%
# 2             0.00%
# 3             0.01%
# 4             0.00%

# %%
dataset.columns
keep_cols = ['State of Residence',
       'Age of Mother 9', 'Age of Mother 9 Code', "Mother's Single Race 6",
       "Mother's Education Code", 'Source of Payment for Delivery',
       'Source of Payment for Delivery Code', 'Births', "% of Total Births"]
new_dataset = dataset[keep_cols]
new_dataset
# Out:
#       State of Residence Age of Mother 9 Age of Mother 9 Code  \
# 0                Alabama  Under 15 years                   15
# 1                Alabama  Under 15 years                   15
# 2                Alabama     15-19 years                15-19
# 3                Alabama     15-19 years                15-19
# 4                Alabama     15-19 years                15-19
# ...                  ...             ...                  ...
# 16578                NaN             NaN                  NaN
# 16579                NaN             NaN                  NaN
# 16580                NaN             NaN                  NaN
# 16581                NaN             NaN                  NaN
# 16582                NaN             NaN                  NaN
#
#           Mother's Single Race 6 Mother's Education Code  \
# 0      Black or African American                       1
# 1                          White                       1
# 2      Black or African American                       1
# 3      Black or African American                       2
# 4      Black or African American                       2
# ...                          ...                     ...
# 16578                        NaN                     NaN
# 16579                        NaN                     NaN
# 16580                        NaN                     NaN
# 16581                        NaN                     NaN
# 16582                        NaN                     NaN
#
#       Source of Payment for Delivery  Source of Payment for Delivery Code  \
# 0                           Medicaid                                  1.0
# 1                           Medicaid                                  1.0
# 2                           Medicaid                                  1.0
# 3                           Medicaid                                  1.0
# 4                  Private Insurance                                  2.0
# ...                              ...                                  ...
# 16578                            NaN                                  NaN
# 16579                            NaN                                  NaN
# 16580                            NaN                                  NaN
# 16581                            NaN                                  NaN
# 16582                            NaN                                  NaN
#
#        Births % of Total Births
# 0        17.0             0.00%
# 1        16.0             0.00%
# 2        28.0             0.00%
# 3       424.0             0.01%
# 4        31.0             0.00%
# ...       ...               ...
# 16578     NaN               NaN
# 16579     NaN               NaN
# 16580     NaN               NaN
# 16581     NaN               NaN
# 16582     NaN               NaN
#
# [16583 rows x 9 columns]

# %% [markdown]
# I could sum the popultion for each race

# %%
race_payment = new_dataset.groupby(["Mother's Single Race 6", 'Source of Payment for Delivery']).agg({'Births':'sum'})
race_payment.reset_index(inplace= True)
race_sum = new_dataset.groupby(["Mother's Single Race 6"]).agg({'Births':'sum'})
race_sum = race_sum.rename(columns={"Births": "Birth_Sum"})
race_sum.reset_index(inplace= True)
merged_df = pd.merge(race_payment, race_sum,how= 'left', on= "Mother's Single Race 6")
race_payment['race_percent'] = round((merged_df['Births']/merged_df['Birth_Sum'])*100, 2)
race_payment
# Out:
#                        Mother's Single Race 6 Source of Payment for Delivery  \
# 0            American Indian or Alaska Native                       Medicaid
# 1            American Indian or Alaska Native                          Other
# 2            American Indian or Alaska Native              Private Insurance
# 3            American Indian or Alaska Native                       Self Pay
# 4            American Indian or Alaska Native          Unknown or Not Stated
# 5                                       Asian                       Medicaid
# 6                                       Asian                          Other
# 7                                       Asian              Private Insurance
# 8                                       Asian                       Self Pay
# 9                                       Asian          Unknown or Not Stated
# 10                  Black or African American                       Medicaid
# 11                  Black or African American                          Other
# 12                  Black or African American              Private Insurance
# 13                  Black or African American                       Self Pay
# 14                  Black or African American          Unknown or Not Stated
# 15                         More than one race                       Medicaid
# 16                         More than one race                          Other
# 17                         More than one race              Private Insurance
# 18                         More than one race                       Self Pay
# 19                         More than one race          Unknown or Not Stated
# 20  Native Hawaiian or Other Pacific Islander                       Medicaid
# 21  Native Hawaiian or Other Pacific Islander                          Other
# 22  Native Hawaiian or Other Pacific Islander              Private Insurance
# 23  Native Hawaiian or Other Pacific Islander                       Self Pay
# 24  Native Hawaiian or Other Pacific Islander          Unknown or Not Stated
# 25                                      White                       Medicaid
# 26                                      White                          Other
# 27                                      White              Private Insurance
# 28                                      White                       Self Pay
# 29                                      White          Unknown or Not Stated
#
#        Births  race_percent
# 0     20796.0         73.60
# 1      1491.0          5.28
# 2      5822.0         20.60
# 3       134.0          0.47
# 4        13.0          0.05
# 5     53327.0         22.67
# 6      4615.0          1.96
# 7    171523.0         72.91
# 8      4792.0          2.04
# 9       996.0          0.42
# 10   378473.0         64.92
# 11    13909.0          2.39
# 12   174451.0         29.93
# 13    13329.0          2.29
# 14     2790.0          0.48
# 15    51076.0         49.78
# 16     3023.0          2.95
# 17    47381.0         46.18
# 18      803.0          0.78
# 19      317.0          0.31
# 20     6485.0         72.65
# 21       64.0          0.72
# 22     2048.0         22.94
# 23      249.0          2.79
# 24       80.0          0.90
# 25  1067946.0         37.46
# 26    85961.0          3.02
# 27  1543782.0         54.15
# 28   134699.0          4.72
# 29    18518.0          0.65

# %%
subset = race_payment[race_payment['Source of Payment for Delivery'] == 'Medicaid']
subset
# Out:
#                        Mother's Single Race 6 Source of Payment for Delivery  \
# 0            American Indian or Alaska Native                       Medicaid
# 5                                       Asian                       Medicaid
# 10                  Black or African American                       Medicaid
# 15                         More than one race                       Medicaid
# 20  Native Hawaiian or Other Pacific Islander                       Medicaid
# 25                                      White                       Medicaid
#
#        Births  race_percent
# 0     20796.0         73.60
# 5     53327.0         22.67
# 10   378473.0         64.92
# 15    51076.0         49.78
# 20     6485.0         72.65
# 25  1067946.0         37.46

# %%
fig, ax = plt.subplots()
races = race_payment['Mother\'s Single Race 6'].unique()


#for race in list of 

#ax.bar(race_payment["Mother's Single Race 6"], race_payment['race_percent'])
# Out:
# ['American Indian or Alaska Native' 'Asian' 'Black or African American'
#  'More than one race' 'Native Hawaiian or Other Pacific Islander' 'White']
